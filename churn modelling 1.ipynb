# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# ### Data Exploration

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df['Surname'].values
# Out:
# array(['Hargrave', 'Hill', 'Onio', ..., 'Liu', 'Sabbatini', 'Walker'],
#       dtype=object)

# %%
df= df.drop('Surname',axis='columns')

# %%
df
# Out:
#       RowNumber  CustomerId  CreditScore Geography  Gender  Age  Tenure  \
# 0             1    15634602          619    France  Female   42       2
# 1             2    15647311          608     Spain  Female   41       1
# 2             3    15619304          502    France  Female   42       8
# 3             4    15701354          699    France  Female   39       1
# 4             5    15737888          850     Spain  Female   43       2
# ...         ...         ...          ...       ...     ...  ...     ...
# 9995       9996    15606229          771    France    Male   39       5
# 9996       9997    15569892          516    France    Male   35      10
# 9997       9998    15584532          709    France  Female   36       7
# 9998       9999    15682355          772   Germany    Male   42       3
# 9999      10000    15628319          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
df['Geography'].values
# Out:
# array(['France', 'Spain', 'France', ..., 'France', 'Germany', 'France'],
#       dtype=object)

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ### Feature Engineering

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['Geography_n'] = le.fit_transform(df['Geography'])

# %%
df
# Out:
#       RowNumber  CustomerId  CreditScore Geography  Gender  Age  Tenure  \
# 0             1    15634602          619    France  Female   42       2
# 1             2    15647311          608     Spain  Female   41       1
# 2             3    15619304          502    France  Female   42       8
# 3             4    15701354          699    France  Female   39       1
# 4             5    15737888          850     Spain  Female   43       2
# ...         ...         ...          ...       ...     ...  ...     ...
# 9995       9996    15606229          771    France    Male   39       5
# 9996       9997    15569892          516    France    Male   35      10
# 9997       9998    15584532          709    France  Female   36       7
# 9998       9999    15682355          772   Germany    Male   42       3
# 9999      10000    15628319          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
df['Gender'] = pd.get_dummies(df['Gender'])

# %%
df
# Out:
#       RowNumber  CustomerId  CreditScore Geography  Gender  Age  Tenure  \
# 0             1    15634602          619    France       1   42       2
# 1             2    15647311          608     Spain       1   41       1
# 2             3    15619304          502    France       1   42       8
# 3             4    15701354          699    France       1   39       1
# 4             5    15737888          850     Spain       1   43       2
# ...         ...         ...          ...       ...     ...  ...     ...
# 9995       9996    15606229          771    France       0   39       5
# 9996       9997    15569892          516    France       0   35      10
# 9997       9998    15584532          709    France       1   36       7
# 9998       9999    15682355          772   Germany       0   42       3
# 9999      10000    15628319          792    France       1   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
df =df.drop('Geography',axis='columns')

# %%
df
# Out:
#       RowNumber  CustomerId  CreditScore  Gender  Age  Tenure    Balance  \
# 0             1    15634602          619       1   42       2       0.00
# 1             2    15647311          608       1   41       1   83807.86
# 2             3    15619304          502       1   42       8  159660.80
# 3             4    15701354          699       1   39       1       0.00
# 4             5    15737888          850       1   43       2  125510.82
# ...         ...         ...          ...     ...  ...     ...        ...
# 9995       9996    15606229          771       0   39       5       0.00
# 9996       9997    15569892          516       0   35      10   57369.61
# 9997       9998    15584532          709       1   36       7       0.00
# 9998       9999    15682355          772       0   42       3   75075.31
# 9999      10000    15628319          792       1   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# ...

# %%
df['EstimatedSalary']
# Out:
# 0       101348.88
# 1       112542.58
# 2       113931.57
# 3        93826.63
# 4        79084.10
#           ...
# 9995     96270.64
# 9996    101699.77
# 9997     42085.58
# 9998     92888.52
# 9999     38190.78
# Name: EstimatedSalary, Length: 10000, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
cols = ['EstimatedSalary','Age','Balance','CreditScore','Tenure']

# %%
df[cols] = scaler.fit_transform(df[cols])

# %%
df
# Out:
#       RowNumber  CustomerId  CreditScore  Gender       Age  Tenure   Balance  \
# 0             1    15634602        0.538       1  0.324324     0.2  0.000000
# 1             2    15647311        0.516       1  0.310811     0.1  0.334031
# 2             3    15619304        0.304       1  0.324324     0.8  0.636357
# 3             4    15701354        0.698       1  0.283784     0.1  0.000000
# 4             5    15737888        1.000       1  0.337838     0.2  0.500246
# ...         ...         ...          ...     ...       ...     ...       ...
# 9995       9996    15606229        0.842       0  0.283784     0.5  0.000000
# 9996       9997    15569892        0.332       0  0.229730     1.0  0.228657
# 9997       9998    15584532        0.718       1  0.243243     0.7  0.000000
# 9998       9999    15682355        0.844       0  0.324324     0.3  0.299226
# 9999      10000    15628319        0.884       1  0.135135     0.4  0.518708
#
# ...

# %%
df = df.drop('CustomerId',axis='columns')

# %%
df = df.drop('RowNumber',axis='columns')

# %%
df
# Out:
#       CreditScore  Gender       Age  Tenure   Balance  NumOfProducts  \
# 0           0.538       1  0.324324     0.2  0.000000              1
# 1           0.516       1  0.310811     0.1  0.334031              1
# 2           0.304       1  0.324324     0.8  0.636357              3
# 3           0.698       1  0.283784     0.1  0.000000              2
# 4           1.000       1  0.337838     0.2  0.500246              1
# ...           ...     ...       ...     ...       ...            ...
# 9995        0.842       0  0.283784     0.5  0.000000              2
# 9996        0.332       0  0.229730     1.0  0.228657              1
# 9997        0.718       1  0.243243     0.7  0.000000              1
# 9998        0.844       0  0.324324     0.3  0.299226              2
# 9999        0.884       1  0.135135     0.4  0.518708              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited  Geography_n
# ...

# %%
x = df.drop('Exited',axis='columns')

# %%
x
# Out:
#       CreditScore  Gender       Age  Tenure   Balance  NumOfProducts  \
# 0           0.538       1  0.324324     0.2  0.000000              1
# 1           0.516       1  0.310811     0.1  0.334031              1
# 2           0.304       1  0.324324     0.8  0.636357              3
# 3           0.698       1  0.283784     0.1  0.000000              2
# 4           1.000       1  0.337838     0.2  0.500246              1
# ...           ...     ...       ...     ...       ...            ...
# 9995        0.842       0  0.283784     0.5  0.000000              2
# 9996        0.332       0  0.229730     1.0  0.228657              1
# 9997        0.718       1  0.243243     0.7  0.000000              1
# 9998        0.844       0  0.324324     0.3  0.299226              2
# 9999        0.884       1  0.135135     0.4  0.518708              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Geography_n
# 0             1               1         0.506735            0
# ...

# %%
y = df['Exited']

# %%
corr = df.corr()

# %%
ax = sns.heatmap(corr)

# %% [markdown]
# ### Model Building

# %%
from sklearn.model_selection import train_test_split

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=5)

# %%
x_train.shape
# Out:
# (7000, 10)

# %%
x_test.shape
# Out:
# (3000, 10)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
model.predict(x_train)
# Out:
# array([0, 0, 1, ..., 0, 0, 1], dtype=int64)

# %%
model.score(x_train,y_train)
# Out:
# 0.808

# %%
model.coef_.mean()
# Out:
# 0.554341349823605

# %%
model.intercept_.mean()
# Out:
# -2.9217975426124623

# %%
from sklearn.model_selection import cross_val_score

# %%
reg = cross_val_score

# %%
reg = cross_val_score(model,x,y,cv=3)

# %%
reg
# Out:
# array([0.80713857, 0.80528053, 0.81068107])

# %%
reg.mean()
# Out:
# 0.8077000561483864

# %%
model.score(x,y)
# Out:
# 0.8087

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier()

# %%
clf.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
clf.score(x,y)
# Out:
# 1.0

# %%
clf.score(x_train,y_train)
# Out:
# 1.0

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier()

# %%
clf.fit(x,y)
# Out:
# RandomForestClassifier()

# %%
clf.score(x_train,y_train)
# Out:
# 1.0

# %% [markdown]
# ### Decision Tree Classifier and Random Forest Classifier gives the 100% score!
